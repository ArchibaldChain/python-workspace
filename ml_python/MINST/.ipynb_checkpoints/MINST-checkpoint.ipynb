# %% [markdown]
# # MINST

# %% [markdown]
# Hand written number recognition

# %%
from sklearn.datasets import fetch_openml
mist = fetch_openml('mnist_784', version=1)
# Out:
# C:\Users\Archibald Chain\AppData\Roaming\Python\Python37\site-packages\sklearn\datasets\openml.py:51: RuntimeWarning: Invalid cache, redownloading file
#   warn("Invalid cache, redownloading file", RuntimeWarning)
# ---------------------------------------------------------------------------
# EOFError                                  Traceback (most recent call last)
# ~\AppData\Roaming\Python\Python37\site-packages\sklearn\datasets\openml.py in wrapper()
#      46             try:
# ---> 47                 return f()
#      48             except HTTPError:
#
# ~\AppData\Roaming\Python\Python37\site-packages\sklearn\datasets\openml.py in _arff_load()
#     387
# --> 388             arff_file = _arff.loads(response.read().decode('utf-8'),
#     389                                     encode_nominal=encode_nominal,
#
# C:\Program Files\Python37\lib\gzip.py in read(self, size)
#     275             raise OSError(errno.EBADF, "read() on write-only GzipFile object")
# --> 276         return self._buffer.read(size)
#     277
#
# C:\Program Files\Python37\lib\gzip.py in read(self, size)
#     481             if buf == b"":
# --> 482                 raise EOFError("Compressed file ended before the "
#     483                                "end-of-stream marker was reached")
#
# EOFError: Compressed file ended before the end-of-stream marker was reached
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-dd52099f59eb> in <module>
#       1 from sklearn.datasets import fetch_openml
# ----> 2 mist = fetch_openml('mnist_784', version=1)
#
# ~\AppData\Roaming\Python\Python37\site-packages\sklearn\datasets\openml.py in fetch_openml(name, version, data_id, data_home, target_column, cache, return_X_y)
#     632     # obtain the data
#     633     arff = _download_data_arff(data_description['file_id'], return_sparse,
# --> 634                                data_home)
#     635
#     636     # nominal attributes is a dict mapping from the attribute name to the
#
# ~\AppData\Roaming\Python\Python37\site-packages\sklearn\datasets\openml.py in _download_data_arff(file_id, sparse, data_home, encode_nominal)
#     391         return arff_file
#     392
# --> 393     return _arff_load()
#     394
#     395
#
# ~\AppData\Roaming\Python\Python37\site-packages\sklearn\datasets\openml.py in wrapper()
#      53                 if os.path.exists(local_path):
#      54                     os.unlink(local_path)
# ---> 55                 return f()
#      56         return wrapper
#      57     return decorator
#
# ~\AppData\Roaming\Python\Python37\site-packages\sklearn\datasets\openml.py in _arff_load()
#     380     @_retry_with_clean_cache(url, data_home)
#     381     def _arff_load():
# --> 382         with closing(_open_openml_url(url, data_home)) as response:
#     383             if sparse is True:
#     384                 return_type = _arff.COO
#
# ~\AppData\Roaming\Python\Python37\site-packages\sklearn\datasets\openml.py in _open_openml_url(openml_path, data_home)
#     101                 if is_gzip(fsrc):
#     102                     with open(local_path, 'wb') as fdst:
# --> 103                         shutil.copyfileobj(fsrc, fdst)
#     104                 else:
#     105                     with gzip.GzipFile(local_path, 'wb') as fdst:
#
# C:\Program Files\Python37\lib\shutil.py in copyfileobj(fsrc, fdst, length)
#      77     """copy data from file-like object fsrc to file-like object fdst"""
#      78     while 1:
# ---> 79         buf = fsrc.read(length)
#      80         if not buf:
#      81             break
#
# C:\Program Files\Python37\lib\http\client.py in read(self, amt)
#     445             # Amount is given, implement using readinto
#     446             b = bytearray(amt)
# --> 447             n = self.readinto(b)
#     448             return memoryview(b)[:n].tobytes()
#     449         else:
#
# C:\Program Files\Python37\lib\http\client.py in readinto(self, b)
#     479
#     480         if self.chunked:
# --> 481             return self._readinto_chunked(b)
#     482
#     483         if self.length is not None:
#
# C:\Program Files\Python37\lib\http\client.py in _readinto_chunked(self, b)
#     584
#     585                 temp_mvb = mvb[:chunk_left]
# --> 586                 n = self._safe_readinto(temp_mvb)
#     587                 mvb = mvb[n:]
#     588                 total_bytes += n
#
# C:\Program Files\Python37\lib\http\client.py in _safe_readinto(self, b)
#     624                 n = self.fp.readinto(temp_mvb)
#     625             else:
# --> 626                 n = self.fp.readinto(mvb)
#     627             if not n:
#     628                 raise IncompleteRead(bytes(mvb[0:total_bytes]), len(b))
#
# C:\Program Files\Python37\lib\socket.py in readinto(self, b)
#     587         while True:
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#     591                 self._timeout_occurred = True
#
# C:\Program Files\Python37\lib\ssl.py in recv_into(self, buffer, nbytes, flags)
#    1050                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1051                   self.__class__)
# -> 1052             return self.read(nbytes, buffer)
#    1053         else:
#    1054             return super().recv_into(buffer, nbytes, flags)
#
# C:\Program Files\Python37\lib\ssl.py in read(self, len, buffer)
#     909         try:
#     910             if buffer is not None:
# --> 911                 return self._sslobj.read(len, buffer)
#     912             else:
#     913                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %% [markdown]
# > https://www.openml.org/d/554

# %%
mnist
