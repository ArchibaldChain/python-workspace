# %%
import math
def f1(x):
    #return math.sqrt(x) - math.cos(x)
    #return pow(x,2) - 1 - math.exp(1-pow(x,2))
    #return pow(x,3) -25
    #return pow(x,3) - x -1
    return (x+2)*pow((x+1),1)*x*pow((x-1),3)*(x-2)

# %%
def bisection(a,b,n, e):
    print("f1(a)=",f1(a), "f1(b)=",f1(b))
    if f1(a)*f1(b) >0:
        return
    for i in range(n):
        print(i)
        c = (a+b)/2
        print("a=", a,"b=", b)
        #print("f1(a)=",f1(a), "f1(b)=",f1(b))
        print("f(p)=", f1(c))
        if (abs(a-b)<e):
            return (a+b)/2
        if f1(c) * f1(a) <= 0:
            b = c
        else:
            a = c
        
    
    return (a+b)/2

# %%
bisection(-1.5, 1.75, 300 , 0.0001)
# Out:
# f1(a)= 20.5078125 f1(b)= -1.90338134765625
# 0
# a= -1.5 b= 1.75
# f(p)= 0.37535905838012695
# 1
# a= 0.125 b= 1.75
# f(p)= 0.0013840757310390472
# 2
# a= 0.9375 b= 1.75
# f(p)= -0.2807120130455587
# 3
# a= 0.9375 b= 1.34375
# f(p)= -0.01832609293501264
# 4
# a= 0.9375 b= 1.140625
# f(p)= -0.0003687967511378787
# 5
# a= 0.9375 b= 1.0390625
# f(p)= 9.560563926161447e-06
# 6
# a= 0.98828125 b= 1.0390625
# f(p)= -1.550556944898793e-05
# 7
# a= 0.98828125 b= 1.013671875
# f(p)= -5.5924784759719815e-09
# 8
# a= 0.98828125 b= 1.0009765625
# f(p)= 9.255093072328412e-07
# 9
# a= 0.99462890625 b= 1.0009765625
# f(p)= 6.3533274914865e-08
# 10
# a= 0.997802734375 b= 1.0009765625
# f(p)= 1.3635477400109903e-09
# 11
# a= 0.9993896484375 b= 1.0009765625
# f(p)= -3.684015489653228e-11
# 12
# a= 0.9993896484375 b= 1.00018310546875
# f(p)= 5.848146310619413e-11
# 13
# a= 0.999786376953125 b= 1.00018310546875
# f(p)= 2.1316011018124044e-14
# 14
# a= 0.9999847412109375 b= 1.00018310546875
# ...

# %%
bisection(1,4,100,0.001)
# Out:
# f1(a)= -2 f1(b)= 64
# 0
# a= 1 b= 4
# f(p)= 14.125
# 1
# a= 1 b= 2.5
# f(p)= 3.109375
# 2
# a= 1 b= 1.75
# f(p)= -0.025390625
# 3
# a= 1.375 b= 1.75
# f(p)= 1.377197265625
# 4
# a= 1.375 b= 1.5625
# f(p)= 0.637176513671875
# 5
# a= 1.375 b= 1.46875
# f(p)= 0.2965202331542969
# 6
# a= 1.375 b= 1.421875
# f(p)= 0.13326025009155273
# 7
# a= 1.375 b= 1.3984375
# f(p)= 0.05336350202560425
# 8
# a= 1.375 b= 1.38671875
# f(p)= 0.013844214379787445
# 9
# a= 1.375 b= 1.380859375
# f(p)= -0.005808685906231403
# 10
# a= 1.3779296875 b= 1.380859375
# f(p)= 0.004008884658105671
# 11
# a= 1.3779296875 b= 1.37939453125
# f(p)= -0.0009021193400258198
# 12
# a= 1.378662109375 b= 1.37939453125
# f(p)= 0.0015528278327110456
# 1.3790283203125

# %%
bisection(-2, 0, 1000 ,0.001)
# Out:
# f1(a)= 2.950212931632136 f1(b)= -3.718281828459045
# 0
# a= -2 b= 0
# f(p)= -1.0
# 1
# a= -2 b= -1.0
# f(p)= 0.9634952031398099
# 2
# a= -1.5 b= -1.0
# f(p)= -0.00728282473092301
# 3
# a= -1.5 b= -1.25
# f(p)= 0.48022582690363
# 4
# a= -1.375 b= -1.25
# f(p)= 0.23719521405913302
# 5
# a= -1.3125 b= -1.25
# f(p)= 0.11515295433753148
# 6
# a= -1.28125 b= -1.25
# f(p)= 0.05398561482037567
# 7
# a= -1.265625 b= -1.25
# f(p)= 0.02336416096493721
# 8
# a= -1.2578125 b= -1.25
# f(p)= 0.008043872959257237
# 9
# a= -1.25390625 b= -1.25
# f(p)= 0.0003813268241048551
# 10
# a= -1.251953125 b= -1.25
# f(p)= -0.0034505480992705895
# 11
# a= -1.251953125 b= -1.2509765625
# f(p)= -0.0015345604456475925
# -1.25146484375
